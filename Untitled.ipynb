# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
X = np.array([1., 3.1, 5.6, 7.4, 9.1])
Y = np.array([1.6, 4, 5.9, 7.9, 10])

# %%
f, ax = plt.subplots(1,1)

# %%
plt.loglog(X, Y, basex=np.e, basey=np.e)
